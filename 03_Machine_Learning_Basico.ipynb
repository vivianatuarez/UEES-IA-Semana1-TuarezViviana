# %% [markdown]
# <a href="https://colab.research.google.com/github/vivianatuarez/UEES-IA-Semana1-TuarezViviana/blob/main/03_Machine_Learning_Basico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris, load_wine
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, pred))
print(classification_report(y_test, pred, target_names=iris.target_names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3445395299.py in <cell line: 0>()
#      11 pred = model.predict(X_test)
#      12
# ---> 13 print("Accuracy:", accuracy_score(y_test, pred))
#      14 print(classification_report(y_test, pred, target_names=iris.target_names))
#
# NameError: name 'accuracy_score' is not defined

# %%
save_to_github("03_Machine_Learning_Basico.ipynb", "ML básico completado")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2495128252.py in <cell line: 0>()
# ----> 1 save_to_github("03_Machine_Learning_Basico.ipynb", "ML básico completado")
#
# NameError: name 'save_to_github' is not defined
